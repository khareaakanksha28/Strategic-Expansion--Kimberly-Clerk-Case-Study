# %%
import pandas as pd

df = pd.read_csv('Data.csv')
# Out:
# /Users/mrudula/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/mrudula/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# ...

# %%
df.head()
# Out:
#               Geography                          Geographic Area Name  \
# 0  1400000US01001020100     Census Tract 201; Autauga County; Alabama
# 1  1400000US01001020200     Census Tract 202; Autauga County; Alabama
# 2  1400000US01001020300     Census Tract 203; Autauga County; Alabama
# 3  1400000US01001020400     Census Tract 204; Autauga County; Alabama
# 4  1400000US01001020501  Census Tract 205.01; Autauga County; Alabama
#
#    Count!!SEX AND AGE!!Total population  \
# 0                                  1775
# 1                                  2055
# 2                                  3216
# 3                                  4246
# 4                                  4322
#
#    Count!!SEX AND AGE!!Total population!!Under 5 years  \
# 0                                                 97
# 1                                                111
# 2                                                169
# 3                                                218
# ...

# %%
df.dtypes
# Out:
# Geography                                                                         object
# Geographic Area Name                                                              object
# Count!!SEX AND AGE!!Total population                                               int64
# Count!!SEX AND AGE!!Total population!!Under 5 years                                int64
# Count!!SEX AND AGE!!Total population!!5 to 9 years                                 int64
#                                                                                    ...
# Percent!!VACANCY RATES!!Homeowner vacancy rate (percent) [4]                      object
# Percent!!VACANCY RATES!!Rental vacancy rate (percent) [5]                         object
# Percent!!HOUSING TENURE!!Occupied housing units                                   object
# Percent!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units     object
# Percent!!HOUSING TENURE!!Occupied housing units!!Renter-occupied housing units    object
# ...

# %%
len(df.columns)
# Out:
# 322

# %%
df.isnull().sum().head(20)
# Out:
# Geography                                               0
# Geographic Area Name                                    0
# Count!!SEX AND AGE!!Total population                    0
# Count!!SEX AND AGE!!Total population!!Under 5 years     0
# Count!!SEX AND AGE!!Total population!!5 to 9 years      0
# Count!!SEX AND AGE!!Total population!!10 to 14 years    0
# Count!!SEX AND AGE!!Total population!!15 to 19 years    0
# Count!!SEX AND AGE!!Total population!!20 to 24 years    0
# Count!!SEX AND AGE!!Total population!!25 to 29 years    0
# Count!!SEX AND AGE!!Total population!!30 to 34 years    0
# Count!!SEX AND AGE!!Total population!!35 to 39 years    0
# Count!!SEX AND AGE!!Total population!!40 to 44 years    0
# Count!!SEX AND AGE!!Total population!!45 to 49 years    0
# Count!!SEX AND AGE!!Total population!!50 to 54 years    0
# Count!!SEX AND AGE!!Total population!!55 to 59 years    0
# Count!!SEX AND AGE!!Total population!!60 to 64 years    0
# ...

# %%
df.drop(df.columns[166:324], axis=1, inplace=True)
len(df.columns)
# Out:
# 166

# %%
df.columns
# Out:
# Index(['Geography', 'Geographic Area Name',
#        'Count!!SEX AND AGE!!Total population',
#        'Count!!SEX AND AGE!!Total population!!Under 5 years',
#        'Count!!SEX AND AGE!!Total population!!5 to 9 years',
#        'Count!!SEX AND AGE!!Total population!!10 to 14 years',
#        'Count!!SEX AND AGE!!Total population!!15 to 19 years',
#        'Count!!SEX AND AGE!!Total population!!20 to 24 years',
#        'Count!!SEX AND AGE!!Total population!!25 to 29 years',
#        'Count!!SEX AND AGE!!Total population!!30 to 34 years',
#        ...
#        'Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!All other vacants',
#        'Count!!VACANCY RATES!!Homeowner vacancy rate (percent) [4]',
#        'Count!!VACANCY RATES!!Rental vacancy rate (percent) [5]',
#        'Count!!HOUSING TENURE!!Occupied housing units',
#        'Count!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units',
# ...

# %%
df.drop(df.columns[-4:-1], axis=1, inplace=True)
len(df.columns)
# Out:
# 163

# %%
df.columns
# Out:
# Index(['Geography', 'Geographic Area Name',
#        'Count!!SEX AND AGE!!Total population',
#        'Count!!SEX AND AGE!!Total population!!Under 5 years',
#        'Count!!SEX AND AGE!!Total population!!5 to 9 years',
#        'Count!!SEX AND AGE!!Total population!!10 to 14 years',
#        'Count!!SEX AND AGE!!Total population!!15 to 19 years',
#        'Count!!SEX AND AGE!!Total population!!20 to 24 years',
#        'Count!!SEX AND AGE!!Total population!!25 to 29 years',
#        'Count!!SEX AND AGE!!Total population!!30 to 34 years',
#        ...
#        'Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For sale only',
#        'Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!Sold, not occupied',
#        'Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!For seasonal, recreational, or occasional use',
#        'Count!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units!!All other vacants',
# ...

# %%
df.tail(5)
# Out:
#                   Geography  \
# 85390  1400000US72153750501
# 85391  1400000US72153750502
# 85392  1400000US72153750503
# 85393  1400000US72153750601
# 85394  1400000US72153750602
#
#                                     Geographic Area Name  \
# 85390  Census Tract 7505.01; Yauco Municipio; Puerto ...
# 85391  Census Tract 7505.02; Yauco Municipio; Puerto ...
# 85392  Census Tract 7505.03; Yauco Municipio; Puerto ...
# 85393  Census Tract 7506.01; Yauco Municipio; Puerto ...
# 85394  Census Tract 7506.02; Yauco Municipio; Puerto ...
#
#        Count!!SEX AND AGE!!Total population  \
# 85390                                  3968
# 85391                                  1845
# 85392                                  2155
# 85393                                  4368
# 85394                                  2587
#
#        Count!!SEX AND AGE!!Total population!!Under 5 years  \
# 85390                                                116
# ...

# %%
df.drop(['Percent!!SEX AND AGE!!Total population!!10 to 14 years'], axis = 1, inplace=True)
len(df.columns)
# Out:
# 162

# %%
df.drop(['Geography'], axis = 1, inplace=True)
len(df.columns)
# Out:
# 161

# %%
df.head()
# Out:
#                            Geographic Area Name  \
# 0     Census Tract 201; Autauga County; Alabama
# 1     Census Tract 202; Autauga County; Alabama
# 2     Census Tract 203; Autauga County; Alabama
# 3     Census Tract 204; Autauga County; Alabama
# 4  Census Tract 205.01; Autauga County; Alabama
#
#    Count!!SEX AND AGE!!Total population  \
# 0                                  1775
# 1                                  2055
# 2                                  3216
# 3                                  4246
# 4                                  4322
#
#    Count!!SEX AND AGE!!Total population!!Under 5 years  \
# 0                                                 97
# 1                                                111
# 2                                                169
# 3                                                218
# 4                                                190
#
#    Count!!SEX AND AGE!!Total population!!5 to 9 years  \
# ...

# %%
count = 0
count_3 = 0
incorrect = []
l1 = []
for i, value in enumerate(df['Geographic Area Name']):
    ls = value.split(";")
    count = count + 1
    if len(ls) == 3:
        count_3 = count_3 + 1
    else:
        incorrect.append(i)
        l1.append(value)
    
print(count, count_3)
# Out:
# 85395 84512

# %%
df.loc[14778:15660, 'Geographic Area Name'] = df.loc[14778:15660, 'Geographic Area Name'].str.replace(',', ';')

# %%
df.loc[14778:15660, 'Geographic Area Name']
# Out:
# 14778    Census Tract 101.01; Fairfield County; Connect...
# 14779    Census Tract 101.02; Fairfield County; Connect...
# 14780    Census Tract 102.01; Fairfield County; Connect...
# 14781    Census Tract 102.02; Fairfield County; Connect...
# 14782      Census Tract 103; Fairfield County; Connecticut
#                                ...
# 15656       Census Tract 9061; Windham County; Connecticut
# 15657       Census Tract 9071; Windham County; Connecticut
# 15658       Census Tract 9072; Windham County; Connecticut
# 15659       Census Tract 9073; Windham County; Connecticut
# 15660       Census Tract 9081; Windham County; Connecticut
# Name: Geographic Area Name, Length: 883, dtype: object

# %%
def county_split(value):
    ls = value.split(';')
    return ls[1]

# %%
df['County'] = df['Geographic Area Name'].apply(county_split)
df.head()
# Out:
#                            Geographic Area Name  \
# 0     Census Tract 201; Autauga County; Alabama
# 1     Census Tract 202; Autauga County; Alabama
# 2     Census Tract 203; Autauga County; Alabama
# 3     Census Tract 204; Autauga County; Alabama
# 4  Census Tract 205.01; Autauga County; Alabama
#
#    Count!!SEX AND AGE!!Total population  \
# 0                                  1775
# 1                                  2055
# 2                                  3216
# 3                                  4246
# 4                                  4322
#
#    Count!!SEX AND AGE!!Total population!!Under 5 years  \
# 0                                                 97
# 1                                                111
# 2                                                169
# 3                                                218
# 4                                                190
#
#    Count!!SEX AND AGE!!Total population!!5 to 9 years  \
# ...

# %%
def state_split(value):
    ls = value.split(';')
    return ls[2]

# %%
df['State'] = df['Geographic Area Name'].apply(state_split)
df.head()
# Out:
#                            Geographic Area Name  \
# 0     Census Tract 201; Autauga County; Alabama
# 1     Census Tract 202; Autauga County; Alabama
# 2     Census Tract 203; Autauga County; Alabama
# 3     Census Tract 204; Autauga County; Alabama
# 4  Census Tract 205.01; Autauga County; Alabama
#
#    Count!!SEX AND AGE!!Total population  \
# 0                                  1775
# 1                                  2055
# 2                                  3216
# 3                                  4246
# 4                                  4322
#
#    Count!!SEX AND AGE!!Total population!!Under 5 years  \
# 0                                                 97
# 1                                                111
# 2                                                169
# 3                                                218
# 4                                                190
#
#    Count!!SEX AND AGE!!Total population!!5 to 9 years  \
# ...

# %%
df.drop(['Geographic Area Name'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    Count!!SEX AND AGE!!Total population  \
# 0                                  1775
# 1                                  2055
# 2                                  3216
# 3                                  4246
# 4                                  4322
#
#    Count!!SEX AND AGE!!Total population!!Under 5 years  \
# 0                                                 97
# 1                                                111
# 2                                                169
# 3                                                218
# 4                                                190
#
#    Count!!SEX AND AGE!!Total population!!5 to 9 years  \
# 0                                                101
# 1                                                112
# 2                                                202
# 3                                                266
# 4                                                214
#
#    Count!!SEX AND AGE!!Total population!!10 to 14 years  \
# ...

# %%
df['AGE_25_to_29'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!25 to 29 years'].transform('sum')
df['AGE_30_to_34'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!30 to 34 years'].transform('sum')
df['AGE_35_to_39'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!35 to 39 years'].transform('sum')
df['AGE_40_to_44'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!40 to 44 years'].transform('sum')
df['AGE_45_to_49'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!45 to 49 years'].transform('sum')
df['AGE_50_to_54'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!50 to 54 years'].transform('sum')
df['AGE_55_to_59'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Total population!!55 to 59 years'].transform('sum')
df.drop(df.columns[1:20], axis=1, inplace=True)
df.head()
# Out:
#    Count!!SEX AND AGE!!Total population  \
# 0                                  1775
# 1                                  2055
# 2                                  3216
# 3                                  4246
# 4                                  4322
#
#    Count!!SEX AND AGE!!Total population!!Selected Age Categories!!18 years and over  \
# 0                                               1370
# 1                                               1584
# 2                                               2485
# 3                                               3344
# 4                                               3369
#
#    Count!!SEX AND AGE!!Total population!!Selected Age Categories!!21 years and over  \
# 0                                               1299
# 1                                               1504
# 2                                               2377
# 3                                               3195
# 4                                               3217
#
# ...

# %%
df.drop(df.columns[0:5], axis=1, inplace=True)
df.head()
# Out:
#    Count!!SEX AND AGE!!Male population  \
# 0                                  868
# 1                                  981
# 2                                 1474
# 3                                 2055
# 4                                 2049
#
#    Count!!SEX AND AGE!!Male population!!Under 5 years  \
# 0                                                 43
# 1                                                 55
# 2                                                 79
# 3                                                108
# 4                                                 96
#
#    Count!!SEX AND AGE!!Male population!!5 to 9 years  \
# 0                                                 48
# 1                                                 61
# 2                                                105
# 3                                                126
# 4                                                106
#
#    Count!!SEX AND AGE!!Male population!!10 to 14 years  \
# ...

# %%
df['Male_population'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Male population'].transform('sum')

# %%
df.head()
# Out:
#    Count!!SEX AND AGE!!Male population  \
# 0                                  868
# 1                                  981
# 2                                 1474
# 3                                 2055
# 4                                 2049
#
#    Count!!SEX AND AGE!!Male population!!Under 5 years  \
# 0                                                 43
# 1                                                 55
# 2                                                 79
# 3                                                108
# 4                                                 96
#
#    Count!!SEX AND AGE!!Male population!!5 to 9 years  \
# 0                                                 48
# 1                                                 61
# 2                                                105
# 3                                                126
# 4                                                106
#
#    Count!!SEX AND AGE!!Male population!!10 to 14 years  \
# ...

# %%
df.drop(df.columns[0:24], axis=1, inplace=True)
df.head()
# Out:
#    Count!!SEX AND AGE!!Female population  \
# 0                                    907
# 1                                   1074
# 2                                   1742
# 3                                   2191
# 4                                   2273
#
#    Count!!SEX AND AGE!!Female population!!Under 5 years  \
# 0                                                 54
# 1                                                 56
# 2                                                 90
# 3                                                110
# 4                                                 94
#
#    Count!!SEX AND AGE!!Female population!!5 to 9 years  \
# 0                                                 53
# 1                                                 51
# 2                                                 97
# 3                                                140
# 4                                                108
#
#    Count!!SEX AND AGE!!Female population!!10 to 14 years  \
# ...

# %%
df['Female_population'] = df.groupby(['County', 'State'])['Count!!SEX AND AGE!!Female population'].transform('sum')
df.head()
# Out:
#    Count!!SEX AND AGE!!Female population  \
# 0                                    907
# 1                                   1074
# 2                                   1742
# 3                                   2191
# 4                                   2273
#
#    Count!!SEX AND AGE!!Female population!!Under 5 years  \
# 0                                                 54
# 1                                                 56
# 2                                                 90
# 3                                                110
# 4                                                 94
#
#    Count!!SEX AND AGE!!Female population!!5 to 9 years  \
# 0                                                 53
# 1                                                 51
# 2                                                 97
# 3                                                140
# 4                                                108
#
#    Count!!SEX AND AGE!!Female population!!10 to 14 years  \
# ...

# %%
df.drop(df.columns[0:27], axis=1, inplace=True)
df.head()
# Out:
#    Count!!RACE!!Total population  Count!!RACE!!Total population!!One Race  \
# 0                           1775                                     1653
# 1                           2055                                     1984
# 2                           3216                                     3039
# 3                           4246                                     3993
# 4                           4322                                     4055
#
#    Count!!RACE!!Total population!!One Race!!White  \
# 0                                            1389
# 1                                             842
# 2                                            2244
# 3                                            3578
# 4                                            3241
#
#    Count!!RACE!!Total population!!One Race!!Black or African American  \
# 0                                                213
# 1                                               1104
# ...

# %%
df['White_population'] = df.groupby(['County', 'State'])['Count!!RACE!!Total population!!One Race!!White'].transform('sum')
df['Black_population'] = df.groupby(['County', 'State'])['Count!!RACE!!Total population!!One Race!!Black or African American'].transform('sum')
df['Asian_population'] = df.groupby(['County', 'State'])['Count!!RACE!!Total population!!One Race!!Asian'].transform('sum')
df.head()
# Out:
#    Count!!RACE!!Total population  Count!!RACE!!Total population!!One Race  \
# 0                           1775                                     1653
# 1                           2055                                     1984
# 2                           3216                                     3039
# 3                           4246                                     3993
# 4                           4322                                     4055
#
#    Count!!RACE!!Total population!!One Race!!White  \
# 0                                            1389
# 1                                             842
# 2                                            2244
# 3                                            3578
# 4                                            3241
#
#    Count!!RACE!!Total population!!One Race!!Black or African American  \
# 0                                                213
# 1                                               1104
# ...

# %%
df.drop(df.columns[0:16], axis=1, inplace=True)
df.head()
# Out:
#    Count!!HISPANIC OR LATINO!!Total population  \
# 0                                         1775
# 1                                         2055
# 2                                         3216
# 3                                         4246
# 4                                         4322
#
#    Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)  \
# 0                                                 76
# 1                                                 43
# 2                                                100
# 3                                                158
# 4                                                156
#
#    Count!!HISPANIC OR LATINO!!Total population!!Not Hispanic or Latino  \
# 0                                               1699
# 1                                               2012
# 2                                               3116
# 3                                               4088
# ...

# %%
df['Hispanic/Latino_population'] = df.groupby(['County', 'State'])['Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)'].transform('sum')
df['Non-Hispanic/Latino_population'] = df.groupby(['County', 'State'])['Count!!HISPANIC OR LATINO!!Total population!!Not Hispanic or Latino'].transform('sum')
df.head()
# Out:
#    Count!!HISPANIC OR LATINO!!Total population  \
# 0                                         1775
# 1                                         2055
# 2                                         3216
# 3                                         4246
# 4                                         4322
#
#    Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)  \
# 0                                                 76
# 1                                                 43
# 2                                                100
# 3                                                158
# 4                                                156
#
#    Count!!HISPANIC OR LATINO!!Total population!!Not Hispanic or Latino  \
# 0                                               1699
# 1                                               2012
# 2                                               3116
# 3                                               4088
# ...

# %%
df.drop(df.columns[0:41], axis=1, inplace=True)
df.head()
# Out:
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household  \
# 0                                                366
# 1                                                277
# 2                                                576
# 3                                                873
# 4                                                895
#
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household!!With own children under 18 [3]  \
# 0                                                125
# 1                                                113
# 2                                                205
# 3                                                284
# 4                                                313
#
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household  \
# 0                                                 32
# 1                                                 36
# 2                                                 77
# ...

# %%
df['Married_population'] = df.groupby(['County', 'State'])['Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household'].transform('sum')
df['Married_population_with_children'] = df.groupby(['County', 'State'])['Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household!!With own children under 18 [3]'].transform('sum')
df.head()
# Out:
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household  \
# 0                                                366
# 1                                                277
# 2                                                576
# 3                                                873
# 4                                                895
#
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household!!With own children under 18 [3]  \
# 0                                                125
# 1                                                113
# 2                                                205
# 3                                                284
# 4                                                313
#
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household  \
# 0                                                 32
# 1                                                 36
# 2                                                 77
# ...

# %%
df['Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'] = df['Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'] + df['Count!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse or partner present:'] + df['Count!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse or partner present:']
df['Unmarried_population'] = df.groupby(['County', 'State'])['Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'].transform('sum')
df.head()
# Out:
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household  \
# 0                                                366
# 1                                                277
# 2                                                576
# 3                                                873
# 4                                                895
#
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Married couple household!!With own children under 18 [3]  \
# 0                                                125
# 1                                                113
# 2                                                205
# 3                                                284
# 4                                                313
#
#    Count!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household  \
# 0                                                280
# 1                                                446
# 2                                                715
# ...

# %%
df.drop(df.columns[0:25], axis=1, inplace=True)
df.head()
# Out:
#    Count!!HOUSING TENURE!!Occupied housing units  \
# 0                                            646
# 1                                            723
# 2                                           1291
# 3                                           1707
# 4                                           1778
#
#    Count!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units  \
# 0                                                509
# 1                                                427
# 2                                                907
# 3                                               1315
# 4                                               1177
#
#    Count!!HOUSING TENURE!!Occupied housing units!!Renter-occupied housing units  \
# 0                                                137
# 1                                                296
# 2                                                384
# 3                                                392
# ...

# %%
df['Owned_household_population'] = df.groupby(['County', 'State'])['Count!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units'].transform('sum')
df['Rented_household_population'] = df.groupby(['County', 'State'])['Count!!HOUSING TENURE!!Occupied housing units!!Renter-occupied housing units'].transform('sum')
df.head()
# Out:
#    Count!!HOUSING TENURE!!Occupied housing units  \
# 0                                            646
# 1                                            723
# 2                                           1291
# 3                                           1707
# 4                                           1778
#
#    Count!!HOUSING TENURE!!Occupied housing units!!Owner-occupied housing units  \
# 0                                                509
# 1                                                427
# 2                                                907
# 3                                               1315
# 4                                               1177
#
#    Count!!HOUSING TENURE!!Occupied housing units!!Renter-occupied housing units  \
# 0                                                137
# 1                                                296
# 2                                                384
# 3                                                392
# ...

# %%
df.drop(df.columns[0:3], axis=1, inplace=True)
df.head()
# Out:
#             County     State  AGE_25_to_29  AGE_30_to_34  AGE_35_to_39  \
# 0   Autauga County   Alabama          3536          3746          3898
# 1   Autauga County   Alabama          3536          3746          3898
# 2   Autauga County   Alabama          3536          3746          3898
# 3   Autauga County   Alabama          3536          3746          3898
# 4   Autauga County   Alabama          3536          3746          3898
#
#    AGE_40_to_44  AGE_45_to_49  AGE_50_to_54  AGE_55_to_59  Male_population  \
# 0          3810          3901          3839          4147            28390
# 1          3810          3901          3839          4147            28390
# 2          3810          3901          3839          4147            28390
# 3          3810          3901          3839          4147            28390
# 4          3810          3901          3839          4147            28390
#
#    ...  White_population  Black_population  Asian_population  \
# ...

# %%
df_new = df.drop_duplicates()
df_new.head()
# Out:
#              County     State  AGE_25_to_29  AGE_30_to_34  AGE_35_to_39  \
# 0    Autauga County   Alabama          3536          3746          3898
# 17   Baldwin County   Alabama         11702         12989         13879
# 61   Barbour County   Alabama          1489          1653          1639
# 70      Bibb County   Alabama          1455          1407          1535
# 78    Blount County   Alabama          3299          3275          3479
#
#     AGE_40_to_44  AGE_45_to_49  AGE_50_to_54  AGE_55_to_59  Male_population  \
# 0           3810          3901          3839          4147            28390
# 17         13750         14336         14726         16567           112627
# 61          1552          1546          1645          1834            13167
# 70          1561          1586          1521          1618            11798
# 78          3553          3979          3939          4064            29197
#
#     ...  White_population  Black_population  Asian_population  \
# ...

# %%
df_new.columns
# Out:
# Index(['County', 'State', 'AGE_25_to_29', 'AGE_30_to_34', 'AGE_35_to_39',
#        'AGE_40_to_44', 'AGE_45_to_49', 'AGE_50_to_54', 'AGE_55_to_59',
#        'Male_population', 'Female_population', 'White_population',
#        'Black_population', 'Asian_population', 'Hispanic/Latino_population',
#        'Non-Hispanic/Latino_population', 'Married_population',
#        'Married_population_with_children', 'Unmarried_population',
#        'Owned_household_population', 'Rented_household_population'],
#       dtype='object')

# %%
df_new['Country'] = 'United States'
# Out:
# /var/folders/8w/f1nm4bk161nf0bdc91693vr40000gn/T/ipykernel_15080/4073830806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Country'] = 'United States'

# %%
df_new['AGE_Sum'] = df_new['AGE_25_to_29'] + df_new['AGE_30_to_34'] + df_new['AGE_35_to_39'] + df_new['AGE_40_to_44'] + df_new['AGE_45_to_49'] + df_new['AGE_50_to_54'] + df_new['AGE_55_to_59']
# Out:
# /var/folders/8w/f1nm4bk161nf0bdc91693vr40000gn/T/ipykernel_15080/1797073823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['AGE_Sum'] = df_new['AGE_25_to_29'] + df_new['AGE_30_to_34'] + df_new['AGE_35_to_39'] + df_new['AGE_40_to_44'] + df_new['AGE_45_to_49'] + df_new['AGE_50_to_54'] + df_new['AGE_55_to_59']

# %%
df_new = df_new.sort_values(by = ['AGE_Sum', 'AGE_25_to_29', 'AGE_30_to_34', 'AGE_35_to_39',
       'AGE_40_to_44', 'AGE_45_to_49', 'AGE_50_to_54', 'AGE_55_to_59',
       'Male_population', 'Female_population', 'White_population',
       'Black_population', 'Asian_population', 'Hispanic/Latino_population',
       'Non-Hispanic/Latino_population', 'Married_population',
       'Married_population_with_children', 'Unmarried_population',
       'Owned_household_population', 'Rented_household_population'], ascending=False)
df_new.head(21)
# Out:
#                        County        State  AGE_25_to_29  AGE_30_to_34  \
# 5584       Los Angeles County   California        806522        785157
# 25152             Cook County     Illinois        437664        418121
# 73262           Harris County        Texas        364673        372613
# 1749          Maricopa County      Arizona        311419        300713
# 10522        San Diego County   California        255005        247478
# 8450            Orange County   California        226922        212443
# 50941            Kings County     New York        253834        256379
# 18586       Miami-Dade County      Florida        176163        191446
# 71671           Dallas County        Texas        222773        211897
# 53135           Queens County     New York        190852        198894
# 80748             King County   Washington        199611        206188
# 45817            Clark County       Nevada        160933        164663
# ...

# %%
df_new.head()
# Out:
#                     County        State  AGE_25_to_29  AGE_30_to_34  \
# 5584    Los Angeles County   California        806522        785157
# 25152          Cook County     Illinois        437664        418121
# 73262        Harris County        Texas        364673        372613
# 1749       Maricopa County      Arizona        311419        300713
# 10522     San Diego County   California        255005        247478
#
#        AGE_35_to_39  AGE_40_to_44  AGE_45_to_49  AGE_50_to_54  AGE_55_to_59  \
# 5584         722012        663959        656712        660660        642219
# 25152        379995        344636        329336        325744        331649
# 73262        354191        320437        303596        279889        269241
# 1749         290948        274238        273144        266072        269283
# 10522        235005        209068        201406        201884        207349
#
#        Male_population  ...  Asian_population  Hispanic/Latino_population  \
# ...

# %%
df_new.to_csv('data_cleaned.csv', index=False)

# %%
df_new.to_excel('data_cleaned.xlsx')
# Out:
# /var/folders/8w/f1nm4bk161nf0bdc91693vr40000gn/T/ipykernel_15080/1097408258.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.2' currently installed).
#   df_new.to_excel('data_cleaned.xlsx')
